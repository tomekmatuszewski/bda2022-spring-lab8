# %%
from pyspark.ml.stat import Summarizer
from pyspark.sql import Row
from pyspark.ml.linalg import Vectors
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.createDataFrame(
    [(1.0, Vectors.dense([1.0, 1.0, 1.0])),
     (1.0, Vectors.dense([3.0, 2.0, 1.0])),
     (0.0, Vectors.dense([1.0, 2.0, 3.0]))],
    ["weight", "features"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create summarizer for multiple metrics "mean" and "count"
summarizer = Summarizer.metrics("mean", "std", "normL2", "count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# compute statistics for multiple metrics with weight
df.select(summarizer.summary(df.features, df.weight)).show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------------------------------------------------------------------------------------------------------------+
# aggregate_metrics(features, weight)                                                                                      |
# +-------------------------------------------------------------------------------------------------------------------------+
# {[2.0,1.5,1.0], [1.4142135623730951,0.7071067811865476,0.0], [3.1622776601683795,2.23606797749979,1.4142135623730951], 2}|
# +-------------------------------------------------------------------------------------------------------------------------+
#
# </div>

# %%
# compute statistics for multiple metrics without weight
df.select(summarizer.summary(df.features)).show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# aggregate_metrics(features, 1.0)                                                                                                                                  |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# {[1.6666666666666665,1.6666666666666665,1.6666666666666665], [1.1547005383792515,0.5773502691896257,1.1547005383792515], [3.3166247903554,3.0,3.3166247903554], 3}|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# </div>

# %%
# compute statistics for single metric "mean" with weight
df.select(Summarizer.mean(df.features, df.weight)).show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+
# mean(features)|
# +--------------+
# [2.0,1.5,1.0] |
# +--------------+
#
# </div>

# %%
# compute statistics for single metric "mean" without weight
df.select(Summarizer.mean(df.features)).show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------------------------------------------+
# mean(features)                                            |
# +----------------------------------------------------------+
# [1.6666666666666665,1.6666666666666665,1.6666666666666665]|
# +----------------------------------------------------------+
#
# </div>
